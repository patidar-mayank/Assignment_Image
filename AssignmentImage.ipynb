# %% [markdown]
# **Import Necessary Library**

# %%
import matplotlib.pyplot as plt
from transformers import BlipProcessor, BlipForConditionalGeneration
import requests
from PIL import Image
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Load the Model**

# %%
# Load a pre-trained BLIP processor
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")

# Load a pre-trained BLIP model
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# **Load the Image**

# %%
url = "/content/sddefault.jpg"

# %% [markdown]
# **Image Visualization**

# %%
# Open the image using PIL
image = Image.open(url)
# Convert the image to a numpy array for matplotlib
image_array = np.array(image)

plt.imshow(image_array)
plt.axis('off')
plt.show()

# %% [markdown]
# **Generate the ouptut for an image**

# %%
image = Image.open(url)

# Prepare the image for the model
inputs = processor(images=image, return_tensors="pt")

# Generate caption
out = model.generate(**inputs)
caption = processor.decode(out[0],skip_special_tokens=True)

print("Generated Caption:",caption)
# Out:
# Generated Caption: a young boy is playing in the rain
